# %%
# imports
import numpy as np
import pandas as pd
import xarray as xr

# %%
next_orig = xr.open_dataarray('./wrf_06.nc')
next_new = xr.open_dataarray('./wrf_2017020500_NG-GR-NQ-BD_maxd02_2017-02-06_next.nc')

# %%
print((next_orig.data.flatten()).mean(),min((next_orig.data.flatten())),max(next_orig.data.flatten()))
next_orig.plot()
# Out:
# 95.70200726165687 0.0 302.0974738437501

# %%
print((next_new.data.flatten()).mean(),min((next_new.data.flatten())),max(next_new.data.flatten()))
next_new.plot()
# Out:
# 95.70200726165687 0.0 302.0974738437501
