# %%
# imports
import numpy
import Nio
import Ngl
from IPython import display
import netCDF4 as nc
from datetime import date
from datetime import timedelta
import xarray as xr
import xesmf as xe

# %%
# reading in files
runs = ['VL-130','VL-100','VL-120']#'VL-110',
def plot(run):
    next_06 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-06_next.nc')
    next_07 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-07_next.nc')
    next_08 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-08_next.nc')
    next_09 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-09_next.nc')
    next_10 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-10_next.nc')
    next_11 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-11_next.nc')
    next_12 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-12_next.nc')
    next_13 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-13_next.nc')
    next_14 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-14_next.nc')
    next_15 = xr.open_dataarray('./wrf_2017020500_'+run+'_maxd02_2017-02-15_next.nc')

    wrf_lst = [next_06, next_07, next_08, next_09, next_10, next_11, next_12, next_13, next_14, next_15]
    sum_arr = next_06.data
    for i in wrf_lst[2:11]:
        sum_arr += i.data
    avg = sum_arr / 10 #13
    avg
    avg[avg == 0.0] = 'nan'
    fn = '/cw3e/mead/projects/cwp103/scratch/ldehaan/Livneh/ptt_2017.nc'
    liv = xr.open_dataset(fn)
    livran = liv['Tmax'][35]
    sub = numpy.subtract(avg, livran)
    new_add = numpy.add(sub, livran)
    new_add.plot()

#vl110 bad file

# %%
plot(runs[0])

# %%
plot(runs[1])

# %%
plot(runs[2])

# %%
fl = "/cw3e/mead/projects/cwp103/production/output/2017020500/cf/VL-120/wrfcf_d02_2017-02-06_00_00_00.nc"
xr.open_dataset(fl)['T_2m'].plot()

# %%
fl1 = "/cw3e/mead/projects/cwp103/production/output/2017020500/cf/VL-100/wrfcf_d02_2017-02-06_00_00_00.nc"
xr.open_dataset(fl1)['T_2m'].plot()

# %%
fl2 = "/cw3e/mead/projects/cwp103/production/output/2017020500/cf/VL-130/wrfcf_d02_2017-02-06_00_00_00.nc"
xr.open_dataset(fl2)['T_2m'].plot()

# %%
def plot2(run):
    next_06 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-06_00_00_00.nc')
    next_07 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-07_00_00_00.nc')
    next_08 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-08_00_00_00.nc')
    next_09 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-09_00_00_00.nc')
    next_10 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-10_00_00_00.nc')
    next_11 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-11_00_00_00.nc')
    next_12 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-12_00_00_00.nc')
    next_13 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-13_00_00_00.nc')
    next_14 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-14_00_00_00.nc')
    next_15 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-15_00_00_00.nc')

    wrf_lst = [next_06, next_07, next_08, next_09, next_10, next_11, next_12, next_13, next_14, next_15]
    sum_arr = next_06.data
    for i in wrf_lst[2:11]:
        sum_arr += i.data
    avg = sum_arr / 10 #13
    avg
    avg[avg == 0.0] = 'nan'
    fn = '/cw3e/mead/projects/cwp103/scratch/ldehaan/Livneh/ptt_2017.nc'
    liv = xr.open_dataset(fn)
    livran = liv['Tmax'][35]
    sub = numpy.subtract(avg, livran)
    new_add = numpy.add(sub, livran)
    new_add.plot()

# %%
plot2(runs[0])
plot2(runs[1])
plot2(runs[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-dac6141c3b4d> in <module>
# ----> 1 plot2(runs[0])
#       2 plot2(runs[1])
#       3 plot2(runs[2])
#
# <ipython-input-15-b10b297e4c46> in plot2(run)
#       1 def plot2(run):
# ----> 2     next_06 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-06_00_00_00.nc')
#       3     next_07 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-07_00_00_00.nc')
#       4     next_08 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-08_00_00_00.nc')
#       5     next_09 = xr.open_dataarray('/cw3e/mead/projects/cwp103/production/output/2017020500/cf/'+run+'/wrfcf_d02_2017-02-09_00_00_00.nc')
#
# ...
